# %%
from llama_cpp import Llama
max_tokens = 2048
# llama_llm = Llama(model_path="/Volumes/4Tera_SSD_2022/llm_models/llama-2-7b-chat.Q5_K_M.gguf", chat_format="llama-2")
llm = Llama(model_path="/Volumes/4Tera_SSD_2022/llm_models/orca-2-13b.Q5_K_M.gguf", chat_format="llama-2", n_ctx=max_tokens)
llm.verbose = False # don't print a bunch of stuff
# Out:
# llama_model_loader: loaded meta data with 22 key-value pairs and 363 tensors from /Volumes/4Tera_SSD_2022/llm_models/orca-2-13b.Q5_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q5_K     [  5120, 32003,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor    8:           blk.0.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.1.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   11:              blk.1.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   13:         blk.1.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   17:           blk.1.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.2.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   20:              blk.2.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   22:         blk.2.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   26:           blk.2.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.3.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.3.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   35:           blk.3.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.4.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   38:              blk.4.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   40:         blk.4.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   43:            blk.4.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   44:           blk.4.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.5.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   47:              blk.5.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   49:         blk.5.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   50:            blk.5.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.5.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   52:            blk.5.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   53:           blk.5.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.6.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   56:              blk.6.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   58:         blk.6.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   59:            blk.6.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.6.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   61:            blk.6.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   62:           blk.6.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.7.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   65:              blk.7.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.7.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   68:            blk.7.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.7.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.7.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   71:           blk.7.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.8.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   74:              blk.8.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   76:         blk.8.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   77:            blk.8.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   78:              blk.8.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.8.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   80:           blk.8.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.9.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   83:              blk.9.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   85:         blk.9.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   86:            blk.9.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   87:              blk.9.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.9.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   89:           blk.9.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   91:             blk.10.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   92:             blk.10.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   94:        blk.10.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   95:           blk.10.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   96:             blk.10.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   97:           blk.10.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   98:          blk.10.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  100:             blk.11.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  101:             blk.11.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  103:        blk.11.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  104:           blk.11.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  105:             blk.11.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  106:           blk.11.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  107:          blk.11.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  108:           blk.11.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  109:             blk.12.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  110:             blk.12.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  111:             blk.12.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  112:        blk.12.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  113:           blk.12.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  114:             blk.12.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  115:           blk.12.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  116:          blk.12.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  117:           blk.12.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  118:             blk.13.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  119:             blk.13.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  120:             blk.13.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  121:        blk.13.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  122:           blk.13.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  123:             blk.13.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  124:           blk.13.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  125:          blk.13.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  126:           blk.13.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  127:             blk.14.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  128:             blk.14.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  129:             blk.14.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  130:        blk.14.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  131:           blk.14.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  132:             blk.14.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  133:           blk.14.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  134:          blk.14.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  135:           blk.14.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  136:             blk.15.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  137:             blk.15.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  138:             blk.15.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  139:        blk.15.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  140:           blk.15.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  141:             blk.15.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  142:           blk.15.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  143:          blk.15.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  144:           blk.15.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  145:             blk.16.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  146:             blk.16.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  147:             blk.16.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  148:        blk.16.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  149:           blk.16.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  150:             blk.16.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  151:           blk.16.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  152:          blk.16.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  153:           blk.16.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  154:             blk.17.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  155:             blk.17.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  156:             blk.17.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  157:        blk.17.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  158:           blk.17.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  159:             blk.17.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  160:           blk.17.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  161:          blk.17.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  162:           blk.17.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  163:             blk.18.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  164:             blk.18.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  165:             blk.18.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  166:        blk.18.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  167:           blk.18.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  168:             blk.18.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  169:           blk.18.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  170:          blk.18.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  171:           blk.18.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  172:             blk.19.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  173:             blk.19.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  174:             blk.19.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  175:        blk.19.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  176:           blk.19.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  177:             blk.19.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  178:           blk.19.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  179:          blk.19.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  180:           blk.19.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  181:             blk.20.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  182:             blk.20.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  183:             blk.20.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  184:        blk.20.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  185:           blk.20.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  186:             blk.20.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  187:           blk.20.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  188:          blk.20.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  189:           blk.20.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  190:             blk.21.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  191:             blk.21.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  192:             blk.21.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  193:        blk.21.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  194:           blk.21.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  195:             blk.21.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  196:           blk.21.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  197:          blk.21.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  198:           blk.21.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  199:             blk.22.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  200:             blk.22.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  202:        blk.22.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  203:           blk.22.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  204:             blk.22.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  205:           blk.22.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  206:          blk.22.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  208:             blk.23.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  209:             blk.23.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  210:             blk.23.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  211:        blk.23.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  212:           blk.23.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  213:             blk.23.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  214:           blk.23.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  215:          blk.23.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  216:           blk.23.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  217:             blk.24.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  218:             blk.24.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  219:             blk.24.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  220:        blk.24.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  221:           blk.24.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  222:             blk.24.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  223:           blk.24.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  224:          blk.24.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  225:           blk.24.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  226:             blk.25.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  227:             blk.25.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  228:             blk.25.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  229:        blk.25.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  230:           blk.25.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  231:             blk.25.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  232:           blk.25.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  233:          blk.25.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  234:           blk.25.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  235:             blk.26.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  236:             blk.26.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  237:             blk.26.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  238:        blk.26.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  239:           blk.26.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  240:             blk.26.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  241:           blk.26.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  242:          blk.26.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  243:           blk.26.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  244:             blk.27.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  245:             blk.27.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  246:             blk.27.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  247:        blk.27.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  248:           blk.27.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  249:             blk.27.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  250:           blk.27.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  251:          blk.27.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  252:           blk.27.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  253:             blk.28.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  254:             blk.28.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  255:             blk.28.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  256:        blk.28.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  257:           blk.28.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  258:             blk.28.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  259:           blk.28.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  260:          blk.28.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  261:           blk.28.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  262:             blk.29.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  263:             blk.29.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  264:             blk.29.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  265:        blk.29.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  266:           blk.29.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  267:             blk.29.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  268:           blk.29.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  269:          blk.29.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  270:           blk.29.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  271:             blk.30.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  272:             blk.30.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  273:             blk.30.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  274:        blk.30.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  275:           blk.30.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  276:             blk.30.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  277:           blk.30.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  278:          blk.30.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  279:           blk.30.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  280:             blk.31.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  281:             blk.31.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  282:             blk.31.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  283:        blk.31.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  284:           blk.31.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  285:             blk.31.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  286:           blk.31.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  287:          blk.31.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  288:           blk.31.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  289:             blk.32.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  290:             blk.32.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  291:             blk.32.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  292:        blk.32.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  293:           blk.32.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  294:             blk.32.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  295:           blk.32.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  296:          blk.32.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  297:           blk.32.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  298:             blk.33.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  299:             blk.33.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  300:             blk.33.attn_v.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  301:        blk.33.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  302:           blk.33.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  303:             blk.33.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  304:           blk.33.ffn_down.weight q5_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  305:          blk.33.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  306:           blk.33.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  307:             blk.34.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  308:             blk.34.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  309:             blk.34.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  310:        blk.34.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  311:           blk.34.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  312:             blk.34.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  313:           blk.34.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  314:          blk.34.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  315:           blk.34.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  316:             blk.35.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  317:             blk.35.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  318:             blk.35.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  319:        blk.35.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  320:           blk.35.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  321:             blk.35.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  322:           blk.35.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  323:          blk.35.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  324:           blk.35.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  325:             blk.36.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  326:             blk.36.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  327:             blk.36.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  328:        blk.36.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  329:           blk.36.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  330:             blk.36.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  331:           blk.36.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  332:          blk.36.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  333:           blk.36.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  334:             blk.37.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  335:             blk.37.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  336:             blk.37.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  337:        blk.37.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  338:           blk.37.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  339:             blk.37.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  340:           blk.37.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  341:          blk.37.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  342:           blk.37.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  343:             blk.38.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  344:             blk.38.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  345:             blk.38.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  346:        blk.38.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  349:           blk.38.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  350:          blk.38.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  351:           blk.38.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  352:             blk.39.attn_q.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  353:             blk.39.attn_k.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  354:             blk.39.attn_v.weight q6_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  355:        blk.39.attn_output.weight q5_K     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_gate.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.ffn_up.weight q5_K     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  358:           blk.39.ffn_down.weight q6_K     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  359:          blk.39.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  360:           blk.39.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  361:               output_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  362:                    output.weight q6_K     [  5120, 32003,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 17
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32003]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32003]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32003]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  19:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  20:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  21:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q5_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# llm_load_vocab: special tokens definition check successful ( 262/32003 ).
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32003
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = mostly Q5_K - Medium
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 8.60 GiB (5.67 BPW)
# llm_load_print_meta: general.name   = LLaMA v2
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: PAD token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.13 MiB
# llm_load_tensors: mem required  = 8801.79 MiB
# ...................................................................................................
# llama_new_context_with_model: n_ctx      = 2048
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: kv self size  = 1600.00 MiB
# llama_build_graph: non-view tensors processed: 924/924
# llama_new_context_with_model: compute buffer total size = 197.07 MiB
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
import time
def stream_prompt(question):
    #ask the question.
    #send 2 messages:
    # - the role the system should play.
    # - the question itself.
    system_message = "You are an assistant who perfectly responds to questions with as many details as possible, without making up facts."
    start_time_seconds = time.time()
    stream = llm.create_chat_completion(
        max_tokens=max_tokens,
        messages = [
            {
                "role": "system",
                "content":  f"<|im_start|>system\n{system_message}<|im_end|>" # Orca has unique prompt formatting.
            },
            {
                "role": "user",
                "content": f"<|im_start|>user\n{question}<|im_end|>\n<|im_start|>assistant"
            }
        ],
        stream = True, #stream each word generated in the answer, so we can immediately start seeing the result (similar to ChatGPT)
    )

    #print out each token/word as it is generated.
    for output in stream:
        choices = output['choices']
        choice = choices[0]
        delta = choice['delta']
        if 'content' in delta:
            print(delta['content'], end='')
    print()

    elapsed_time_seconds = time.time() - start_time_seconds
    print(f'answer generated in {elapsed_time_seconds} seconds')

# %%
prompt = """
What is 22 + 45 / 62?
"""

stream_prompt(prompt)
# Out:
# First, we need to perform the division operation: \n45 / 62 = 0.7320931846153844\nThen, we can add this result to 22: \n22 + 0.7320931846153844 = 22.732093184615384\nSo, the final answer is approximately 22.73.
# answer generated in 37.61600089073181 seconds

# %%
stream_prompt("""
I would like you to add words together, using the following logic to determine the numeric value for each letter of the alphabet:
a = 2
b = 4
c = 6
Based on that you should be able to infer that d = 8, etc.

With that understanding, you should now learn that adding 2 words would look similar to the following examples:
bac + dad = 30
da + bc = 20

What is
cat + dog?
""")
#4+2+6  + 8+2+8 = 12 + 18 = 30
# Out:
# To find the numeric value of the word "cat" using the given logic, we can break it down into its individual letters: c (2) and a (1). The sum of these values is 3. Now, to find the numeric value for the word "dog," we can do the same: d (4), o (6), and g (7). The sum of these values is 17.
#
# Using the logic demonstrated in the examples provided, adding two words together involves finding the sum of their corresponding numeric values. In this case, the sum would be 3 (cat) + 17 (dog) = 20. Therefore, cat + dog equals 20.
# answer generated in 48.747461795806885 seconds

# %%
stream_prompt("""
I would like you to determine how to calculate the value of a letter in the evaluating the following examples, and finding a pattern:
a = 2
b = 4
c = 6
d = 8
e = 10
f = 12
g = 14
h = 16
i = 18
j = 20
k = 22
l = 24
m = 26
n = 28
o = 30
p = 32
q = 34
r = 36
s = 38
t = 40
u = 42
v = 44
w = 46
x = 48
y = 50
z = 52

Based on the pattern you find, please list out the value for first 10 letters of the alphabet.
If your response includes a value for a letter that doesn't match the above examples, you should understand that the pattern you came up with is incorrect, and try finding another pattern.
If needed, try coming up with 3 possible patterns.  List out each pattern you come up with, and why it works or doesn't work.
""")
# Out:
# To determine the value of a letter in the given examples, we can observe that there is an increasing difference between consecutive letters. Let's analyze the differences:
#
# d - b = 8 - 4 = 4
# e - d = 10 - 8 = 2
# f - e = 12 - 10 = 2
# g - f = 14 - 12 = 2
# h - g = 16 - 14 = 2
# i - h = 18 - 16 = 2
# j - i = 20 - 18 = 2
# k - j = 22 - 20 = 2
# l - k = 24 - 22 = 2
# m - l = 26 - 24 = 2
# n - m = 28 - 26 = 2
# o - n = 30 - 28 = 2
# p - o = 32 - 30 = 2
# q - p = 34 - 32 = 2
# r - q = 36 - 34 = 2
# s - r = 38 - 36 = 2
# t - s = 40 - 38 = 2
# u - t = 42 - 40 = 2
# v - u = 44 - 42 = 2
# w - v = 46 - 44 = 2
# x - w = 48 - 46 = 2
# y - x = 50 - 48 = 2
# z - y = 52 - 50 = 2
#
# The pattern we observe is that the difference between consecutive letters increases by 2 each time. We can use this pattern to find the value of the first 10 letters:
#
# a = 2 (difference between a and b)
# b = 4 (difference between b and c)
# c = 6 (difference between c and d)
# d = 8 (difference between d and e)
# e = 10 (difference between e and f)
# f = 12 (difference between f and g)
# g = 14 (difference between g and h)
# h = 16 (difference between h and i)
# i = 18 (difference between i and j)
# j = 20 (difference between j and k)
# k = 22 (difference between k and l)
# l = 24 (difference between l and m)
# m = 26 (difference between m and n)
# n = 28 (difference between n and o)
# o = 30 (difference between o and p)
# p = 32 (difference between p and q)
# q = 34 (difference between q and r)
# r = 36 (difference between r and s)
# s = 38 (difference between s and t)
# t = 40 (difference between t and u)
# u = 42 (difference between u and v)
# v = 44 (difference between v and w)
# w = 46 (difference between w and x)
# x = 48 (difference between x and y)
# y = 50 (difference between y and z)
# z = 52 (difference between z and none)
#
# Using this pattern, the first 10 letters have the following values:
#
# a = 2
# b = 4
# c = 6
# d = 8
# e = 10
# f = 12
# g = 14
# h = 16
# i = 18
# j = 20
# k = 22
# answer generated in 259.1865050792694 seconds

# %%
stream_prompt("""
I would like you to determine how to calculate the value of a letter in the evaluating the following examples, and finding a pattern:
a = 2
b = 4
c = 6
d = 8
e = 10
f = 12
g = 14
h = 16
i = 18
j = 20
k = 22
l = 24
m = 26
n = 28
o = 30
p = 32
q = 34
r = 36
s = 38
t = 40
u = 42
v = 44
w = 46
x = 48
y = 50
z = 52

Based on the pattern you find, please list out the value for first 10 letters of the alphabet.
If your response includes a value for a letter that doesn't match the above examples, you should understand that the pattern you came up with is incorrect, and try finding another pattern.
Don't list out the calculation and reasoning for every letter in the alphabet.
Just list out the value for first 10 letters of the alphabet.
""")
# Out:
# To determine the value of each letter, we can observe that there is an increasing difference of 6 between consecutive letters. Let's find the value of the first 10 letters:
#
# a = 2 (first letter)
# b = 2 + 6 = 8 (second letter)
# c = 8 + 6 = 14 (third
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 stream_prompt("""
#       2 I would like you to determine how to calculate the value of a letter in the evaluating the following examples, and finding a pattern:
#       3 a = 2
#       4 b = 4
#       5 c = 6
#       6 d = 8
#       7 e = 10
#       8 f = 12
#       9 g = 14
#      10 h = 16
#      11 i = 18
#      12 j = 20
#      13 k = 22
#      14 l = 24
#      15 m = 26
#      16 n = 28
#      17 o = 30
#      18 p = 32
#      19 q = 34
#      20 r = 36
#      21 s = 38
#      22 t = 40
#      23 u = 42
#      24 v = 44
#      25 w = 46
#      26 x = 48
#      27 y = 50
#      28 z = 52
#      29
#      30 Based on the pattern you find, please list out the value for first 10 letters of the alphabet.
#      31 If your response includes a value for a letter that doesn't match the above examples, you should understand that the pattern you came up with is incorrect, and try finding another pattern.
#      32 Don't list out the calculation and reasoning for every letter in the alphabet.
#      33 Just list out the value for first 10 letters of the alphabet.
#      34 """)
#
# Cell In[19], line 25, in stream_prompt(question)
#       9 stream = llm.create_chat_completion(
#      10     max_tokens=max_tokens,
#      11     messages = [
#    (...)
#      21     stream = True, #stream each word generated in the answer, so we can immediately start seeing the result (similar to ChatGPT)
#      22 )
#      24 #print out each token/word as it is generated.
# ---> 25 for output in stream:
#      26     choices = output['choices']
#      27     choice = choices[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama_chat_format.py:222, in _convert_text_completion_chunks_to_chat(chunks)
#     219 def _convert_text_completion_chunks_to_chat(
#     220     chunks: Iterator[llama_types.CreateCompletionStreamResponse],
#     221 ) -> Iterator[llama_types.ChatCompletionChunk]:
# --> 222     for i, chunk in enumerate(chunks):
#     223         if i == 0:
#     224             yield {
#     225                 "id": "chat" + chunk["id"],
#     226                 "model": chunk["model"],
#    (...)
#     237                 ],
#     238             }
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama.py:1434, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1432 finish_reason = "length"
#    1433 multibyte_fix = 0
# -> 1434 for token in self.generate(
#    1435     prompt_tokens,
#    1436     top_k=top_k,
#    1437     top_p=top_p,
#    1438     min_p=min_p,
#    1439     typical_p=typical_p,
#    1440     temp=temperature,
#    1441     tfs_z=tfs_z,
#    1442     mirostat_mode=mirostat_mode,
#    1443     mirostat_tau=mirostat_tau,
#    1444     mirostat_eta=mirostat_eta,
#    1445     frequency_penalty=frequency_penalty,
#    1446     presence_penalty=presence_penalty,
#    1447     repeat_penalty=repeat_penalty,
#    1448     stopping_criteria=stopping_criteria,
#    1449     logits_processor=logits_processor,
#    1450     grammar=grammar,
#    1451 ):
#    1452     if token == self._token_eos:
#    1453         text = self.detokenize(completion_tokens)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama.py:1209, in Llama.generate(self, tokens, top_k, top_p, min_p, typical_p, temp, repeat_penalty, reset, frequency_penalty, presence_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, logits_processor, stopping_criteria, grammar)
#    1206     grammar.reset()
#    1208 while True:
# -> 1209     self.eval(tokens)
#    1210     token = self.sample(
#    1211         top_k=top_k,
#    1212         top_p=top_p,
#    (...)
#    1224         grammar=grammar,
#    1225     )
#    1226     if stopping_criteria is not None and stopping_criteria(
#    1227         self._input_ids, self._scores[-1, :]
#    1228     ):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama.py:1030, in Llama.eval(self, tokens)
#    1026 n_tokens = len(batch)
#    1027 self._batch.set_batch(
#    1028     batch=batch, n_past=n_past, logits_all=self.context_params.logits_all
#    1029 )
# -> 1030 self._ctx.decode(self._batch)
#    1031 # Save tokens
#    1032 self.input_ids[n_past : n_past + n_tokens] = batch
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama.py:466, in _LlamaContext.decode(self, batch)
#     464 assert self.ctx is not None
#     465 assert batch.batch is not None
# --> 466 return_code = llama_cpp.llama_decode(
#     467     ctx=self.ctx,
#     468     batch=batch.batch,
#     469 )
#     470 if return_code != 0:
#     471     raise RuntimeError(f"llama_decode returned {return_code}")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/llama_cpp/llama_cpp.py:1193, in llama_decode(ctx, batch)
#    1192 def llama_decode(ctx: llama_context_p, batch: llama_batch) -> int:
# -> 1193     return _lib.llama_decode(ctx, batch)
#
# KeyboardInterrupt:

# %%
def count_tokens(text):
    tokens = llm.tokenize(text.encode('utf-8'))
    return len(tokens)

count_tokens("hello I am jason")
# Out:
# 6
